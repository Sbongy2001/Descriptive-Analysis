# %% [markdown]
# # Cadiofitness

# %% [markdown]
# **Author:** Sbongile Mkhize <br> **Student number:** 223149039 <br>**Date:** 10 April 2023 <br>**Source:** https://www.kaggle.com/datasets/saurav9786/cardiogoodfitness <br> **Github url:**

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
Cadiofitness = pd.read_csv('https://raw.githubusercontent.com/Sbongy2001/Descriptive-Analysis/main/CardioGoodFitness.csv')
Cadiofitness.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
Cadiofitness.describe().T
# Out:
#            count          mean           std      min       25%      50%  \
# Age        180.0     28.788889      6.943498     18.0     24.00     26.0
# Education  180.0     15.572222      1.617055     12.0     14.00     16.0
# Usage      180.0      3.455556      1.084797      2.0      3.00      3.0
# Fitness    180.0      3.311111      0.958869      1.0      3.00      3.0
# Income     180.0  53719.577778  16506.684226  29562.0  44058.75  50596.5
# Miles      180.0    103.194444     51.863605     21.0     66.00     94.0
#
#                 75%       max
# Age           33.00      50.0
# Education     16.00      21.0
# Usage          4.00       7.0
# Fitness        4.00       5.0
# Income     58668.00  104581.0
# Miles        114.75     360.0

# %% [markdown]
# ### Cleaning data

# %%
Cadiofitness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
Cadiofitness.shape
# Out:
# (180, 9)

# %%
Cadiofitness.isna().any()
# Out:
# Product          False
# Age              False
# Gender           False
# Education        False
# MaritalStatus    False
# Usage            False
# Fitness          False
# Income           False
# Miles            False
# dtype: bool

# %% [markdown]
# ### Calculations

# %%
Cadiofitness['Age'].max()-Cadiofitness['Age'].min()
# Out:
# 32

# %%
Cadiofitness.mode()
# Out:
#   Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   25   Male         16     Partnered      3        3   45480     85

# %%
five_num = [Cadiofitness["Age"].quantile(0),
           Cadiofitness["Age"].quantile(0.25),
           Cadiofitness["Age"].quantile(0.50),
           Cadiofitness["Age"].quantile(0.75),
           Cadiofitness["Age"].quantile(1)]
five_num
# Out:
# [18.0, 24.0, 26.0, 33.0, 50.0]

# %%
Cadiofitness["Age"].quantile(0.75) - Cadiofitness["Age"].quantile(0.25)
# Out:
# 9.0

# %%
Cadiofitness["Age"].var()
# Out:
# 48.21216635630043

# %%
abs_median_devs = abs(Cadiofitness["Age"] - Cadiofitness["Age"].median())

abs_median_devs.median() * 1.4826
# Out:
# 5.9304

# %%
Cadiofitness["Age"].skew()
# Out:
# 0.9821608255301499

# %%
Cadiofitness["Age"].kurt()
# Out:
# 0.40970995683644373

# %%
Cadiofitness.cov()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12564\1836646901.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Cadiofitness.cov()
#                     Age     Education        Usage      Fitness        Income  \
# Age           48.212166      3.149410     0.113470     0.406828  5.884446e+04
# Education      3.149410      2.614867     0.693172     0.636623  1.670472e+04
# Usage          0.113470      0.693172     1.176785     0.695469  9.303043e+03
# Fitness        0.406828      0.636623     0.695469     0.919429  8.467925e+03
# Income     58844.463439  16704.717815  9303.042582  8467.925388  2.724706e+08
# Miles         13.186530     25.770795    42.709808    39.073246  4.652654e+05
#
#                    Miles
# Age            13.186530
# Education      25.770795
# Usage          42.709808
# ...

# %% [markdown]
# ### Graphs

# %%
sns.distplot(Cadiofitness['Age'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12564\2499825433.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Cadiofitness['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
Cadiofitness.hist(figsize=(5,8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(Cadiofitness["Age"])
plt.title("Age", size=10)
plt.show()

# %%
sns.lineplot(Cadiofitness)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Age", y="Income",data=Cadiofitness)
plt.show()

# %%
corr = Cadiofitness.corr()
corr
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12564\2530801580.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = Cadiofitness.corr()
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### The Python programming language is suitable for complex calculations and large amounts of data. The most common use of Excel is to organize data and perform financial analysis. It stores large amounts of data in workbooks that contain one or more worksheets. In comparison with Python, Excel was much easier to understand because it was not case sensitive. Although Excel was easier for me, it was time consuming, and Python is better because you can calculate for all rows or columns with one code. In contrast, excel requires you to do most of the calculations from scratch, whereas Python is simpler and you can also find some code online. In the future, I will make my work neater and include more calculations not covered in class. Due to Python's case sensitivity, I made a lot of mistakes and had errors in my programming.
